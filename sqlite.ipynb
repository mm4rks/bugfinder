# %% [markdown]
# # Filter sqlite database
#
# - TODO: execute this from worker to populate small tables for each commit
# - TODO: Better grouping for large exception texts that only slightly differ

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
con = sqlite3.connect("samples.sqlite3")
df = pd.read_sql_query("SELECT * from dewolf", con)
con.close()
print("#records:", len(df.index))
# Out:
# #records: 642998

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642998 entries, 0 to 642997
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          642998 non-null  int64
#  1   function_name               642998 non-null  object
#  2   function_basic_block_count  642998 non-null  int64
#  3   function_size               642998 non-null  int64
#  4   function_arch               642998 non-null  object
#  5   function_platform           642998 non-null  object
#  6   sample_hash                 642998 non-null  object
#  7   sample_name                 642998 non-null  object
#  8   dewolf_options              642998 non-null  object
#  9   dewolf_current_commit       642998 non-null  object
#  10  binaryninja_version         642998 non-null  object
#  11  dewolf_exception            231507 non-null  object
#  12  dewolf_traceback            231507 non-null  object
#  13  dewolf_decompilation_time   411491 non-null  float64
#  14  dewolf_undecorated_code     411491 non-null  object
#  15  is_successful               642998 non-null  int64
# dtypes: float64(1), int64(4), object(11)
# memory usage: 78.5+ MB

# %% [markdown]
# # Failed decompilations (functions)

# %%
failed_runs = df[df.is_successful == 0]
print("# failed runs:", len(failed_runs.index))
# Out:
# # failed runs: 231507

# %% [markdown]
# ## Exceptions

# %%
print("Unique exceptions:", len(failed_runs.dewolf_exception.unique()))
# Out:
# Unique exceptions: 80

# %%
for index, value in failed_runs.dewolf_exception.value_counts().items():
    print(f"{value}:", index.strip())
# Out:
# 224517: RuntimeError: 'NoneType' object has no attribute 'getInstructions'
# 4727: AssertionError: Can not remove the root node!
# 668: ValueError: The given set of variables is not an independent set. At least two variables interfere!
# 610: RuntimeError: did not expect to reach canary check this way
# 604: ValueError: Couldn't find target for type
# 221: RuntimeError: argument of type 'NoneType' is not iterable
# 18: AttributeError: 'MediumLevelILSyscallSsa' object has no attribute 'dest'
# 14: ValueError: No switch variable candidate found.
# 9: KeyError: 512
# 8: OverflowError: cannot convert float infinity to integer
# 6: KeyError: 224
# 6: KeyError: 48
# 5: AttributeError: 'MediumLevelILFunction' object has no attribute '_arch'
# 5: KeyError: 24
# 4: KeyError: 80
# 4: RuntimeError
# 4: KeyError: 96
# 4: KeyError: 8
# 4: ValueError: The children of Sequence can not be sorted due to circular reachability
# 3: TypeError: 'NoneType' object is not iterable
# 3: AttributeError: 'Branch' object has no attribute 'destination'
# 2: KeyError: 56
# 2: ctypes.ArgumentError: argument 1: <class 'RecursionError'>: maximum recursion depth exceeded while calling a Python object
# 2: ValueError: Did not expect a Constant/Unknown/Operation with more then 1 operand as a ForLoop declaration
# 2: RuntimeError: Unexpected size 1
# 1: ValueError: At least two variables in the identity group {var_58#2 (type: int aliased: True), var_58#4 (type: int aliased: True), var_58#0 (type: int aliased: True), var_58#8 (type: int aliased: True), var_58#7 (type: int aliased: True), var_58#6 (type: int aliased: True)} have out degree zero, namely var_58#7 and var_58#6, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_14#6 (type: long aliased: False), rax_6#16 (type: long aliased: False), var_c0#0 (type: long aliased: False), var_c0#6 (type: long aliased: False), var_c0#2 (type: long aliased: False)} have out degree zero, namely rax_14#6 and rax_6#16, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_48#4 (type: char * aliased: False), var_48#0 (type: char * aliased: False), var_48#2 (type: char * aliased: False), var_48#12 (type: char * aliased: False), rax_1#3 (type: char * aliased: False), rdx#3 (type: char * aliased: False)} have out degree zero, namely var_48#4 and rax_1#3, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {0 type: long, rax_5#11 (type: long * aliased: False), var_1098#2 (type: long * aliased: False), var_1098#4 (type: long * aliased: False), var_1098#8 (type: long * aliased: False), var_1098#5 (type: long * aliased: False), var_1098#6 (type: long * aliased: False)} have out degree zero, namely 0x0 and rax_5#11, i.e., these set of vertices is not an identity group
# 1: networkx.exception.NetworkXError: The node case 0x73: is not in the digraph.
# 1: ValueError: At least two variables in the identity group {rbp_2#10 (type: DIR * aliased: False), rax_26#55 (type: DIR * aliased: False), rbp_2#8 (type: DIR * aliased: False), rax_26#54 (type: DIR * aliased: False), rax_26#56 (type: DIR * aliased: False), rbp_3#12 (type: DIR * aliased: False), rbx_5#14 (type: DIR * aliased: False), var_50#0 (type: DIR * aliased: False)} have out degree zero, namely rax_26#56 and rbx_5#14, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {arg6#4 (type: unsigned long aliased: False), arg6#2 (type: unsigned long aliased: False), arg4#0 (type: unsigned long aliased: False), var_70#0 (type: unsigned long aliased: False), arg4#11 (type: unsigned long aliased: False)} have out degree zero, namely arg6#2 and arg4#0, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_27#20 (type: long aliased: False), rax_30#3 (type: long aliased: False), var_c0#2 (type: long aliased: False), var_c0#6 (type: long aliased: False), var_c0#0 (type: long aliased: False)} have out degree zero, namely rax_27#20 and rax_30#3, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_88#4 (type: void * aliased: False), var_88#2 (type: void * aliased: False), var_88#1 (type: void * aliased: False), var_88#0 (type: void * aliased: False), var_88#3 (type: void * aliased: False)} have out degree zero, namely var_88#2 and var_88#1, i.e., these set of vertices is not an identity group
# 1: AssertionError: Node case "add_to_previous_case": is not in the AST.
# 1: KeyError: 12468
# 1: ValueError: At least two variables in the identity group {var_2048#0 (type: void aliased: True), var_2048#15 (type: void aliased: True), var_2048#21 (type: void aliased: True), var_2048#31 (type: void aliased: True), var_2048#33 (type: void aliased: True), var_2048#34 (type: void aliased: True), var_2048#13 (type: void aliased: True)} have out degree zero, namely var_2048#15 and var_2048#33, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_c8#54 (type: void aliased: True), var_c8#12 (type: void aliased: True), var_c8#14 (type: void aliased: True), var_c8#48 (type: void aliased: True), var_c8#59 (type: void aliased: True), var_c8#38 (type: void aliased: True), var_c8#9 (type: void aliased: True), var_c8#22 (type: void aliased: True), var_c8#18 (type: void aliased: True), var_c8#7 (type: void aliased: True), var_c8#23 (type: void aliased: True), var_c8#28 (type: void aliased: True), var_c8#26 (type: void aliased: True), var_c8#1 (type: void aliased: True), var_c8#44 (type: void aliased: True), var_c8#52 (type: void aliased: True), var_c8#36 (type: void aliased: True), var_c8#0 (type: void aliased: True), var_c8#4 (type: void aliased: True), var_c8#56 (type: void aliased: True), var_c8#40 (type: void aliased: True), var_c8#42 (type: void aliased: True)} have out degree zero, namely var_c8#48 and var_c8#18, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_50#3 (type: long() * aliased: False), arg4#3 (type: long() * aliased: False), var_50#0 (type: long() * aliased: False), rax_16#19 (type: long() * aliased: False), arg4#0 (type: long() * aliased: False), var_50#1 (type: long() * aliased: False)} have out degree zero, namely rax_16#19 and arg4#0, i.e., these set of vertices is not an identity group
# 1: networkx.exception.NetworkXError: The node case 0x10: is not in the digraph.
# 1: ValueError: At least two variables in the identity group {var_70#4 (type: unsigned long aliased: False), var_70#2 (type: unsigned long aliased: False), var_70#0 (type: unsigned long aliased: False), var_70#1 (type: unsigned long aliased: False), var_70#3 (type: unsigned long aliased: False)} have out degree zero, namely var_70#1 and var_70#3, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_50#18 (type: void * aliased: True), var_50#20 (type: void * aliased: True), var_50#7 (type: void * aliased: True), var_50#13 (type: void * aliased: True), var_50#9 (type: void * aliased: True), var_50#16 (type: void * aliased: True), var_50#0 (type: void * aliased: True), var_50#4 (type: void * aliased: True)} have out degree zero, namely var_50#18 and var_50#9, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_48#23 (type: unsigned long aliased: True), var_48#39 (type: unsigned long aliased: True), var_48#16 (type: unsigned long aliased: True), var_48#34 (type: unsigned long aliased: True), var_48#24 (type: unsigned long aliased: True), var_48#44 (type: unsigned long aliased: True), var_48#18 (type: unsigned long aliased: True), var_48#22 (type: unsigned long aliased: True), var_48#2 (type: unsigned long aliased: True), var_48#0 (type: unsigned long aliased: True), var_48#40 (type: unsigned long aliased: True), var_48#15 (type: unsigned long aliased: True), var_48#17 (type: unsigned long aliased: True), var_48#19 (type: unsigned long aliased: True), var_48#43 (type: unsigned long aliased: True), var_48#21 (type: unsigned long aliased: True), var_48#1 (type: unsigned long aliased: True), var_48#31 (type: unsigned long aliased: True), var_48#45 (type: unsigned long aliased: True), var_48#20 (type: unsigned long aliased: True), var_48#33 (type: unsigned long aliased: True), var_48#36 (type: unsigned long aliased: True), var_48#27 (type: unsigned long aliased: True), var_48#30 (type: unsigned long aliased: True), var_48#41 (type: unsigned long aliased: True)} have out degree zero, namely var_48#15 and var_48#27, i.e., these set of vertices is not an identity group
# 1: networkx.exception.NetworkXError: The node case 0xe: is not in the digraph.
# 1: KeyError: 104
# 1: ValueError: list.remove(x): x not in list
# 1: ValueError: At least two variables in the identity group {var_160#17 (type: long() * aliased: True), var_160#14 (type: long() * aliased: True), var_160#0 (type: long() * aliased: True), var_160#18 (type: long() * aliased: True), var_160#21 (type: long() * aliased: True), var_160#3 (type: long() * aliased: True), var_160#23 (type: long() * aliased: True)} have out degree zero, namely var_160#17 and var_160#21, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rbx_2#5 (type: void * aliased: False), rbp_3#3 (type: void * aliased: False), rbp_3#4 (type: void * aliased: False), rbx_2#4 (type: void * aliased: False), var_50#0 (type: void * aliased: False)} have out degree zero, namely rbx_2#5 and rbp_3#4, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_38#5 (type: long aliased: False), var_1f0#10 (type: long aliased: False), rax_32#29 (type: long aliased: False), var_1f0#2 (type: long aliased: False), rax_15#14 (type: long aliased: False), var_1f0#14 (type: long aliased: False), rax_24#45 (type: long aliased: False), var_1f0#6 (type: long aliased: False), var_1f0#0 (type: long aliased: False)} have out degree zero, namely rax_38#5 and rax_32#29, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_e0#1 (type: void * aliased: False), var_e0#4 (type: void * aliased: False), var_e0#2 (type: void * aliased: False), var_e0#0 (type: void * aliased: False), rax_51#57 (type: void * aliased: False)} have out degree zero, namely var_e0#1 and rax_51#57, i.e., these set of vertices is not an identity group
# 1: networkx.exception.NetworkXError: The node case 0x3: is not in the digraph.
# 1: ValueError: At least two variables in the identity group {var_438#6 (type: long aliased: True), var_438#13 (type: long aliased: True), var_438#0 (type: long aliased: True), var_438#4 (type: long aliased: True), var_438#11 (type: long aliased: True), var_438#19 (type: long aliased: True), var_438#3 (type: long aliased: True)} have out degree zero, namely var_438#6 and var_438#11, i.e., these set of vertices is not an identity group
# 1: KeyError: TransitionBlock(-0x1, AST=var_1 = arg1)
# 1: ValueError: At least two variables in the identity group {var_30#2 (type: long aliased: False), rax_6#23 (type: long aliased: False), var_30#6 (type: long aliased: False), var_30#0 (type: long aliased: False), rax_16#13 (type: long aliased: False)} have out degree zero, namely rax_6#23 and rax_16#13, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_60#14 (type: long * aliased: False), var_60#0 (type: long * aliased: False), rax_30#36 (type: long * aliased: False), var_60#10 (type: long * aliased: False), rax_24#25 (type: long * aliased: False), var_60#2 (type: long * aliased: False), var_60#6 (type: long * aliased: False), rax_38#13 (type: long * aliased: False), rax_16#47 (type: long * aliased: False)} have out degree zero, namely rax_30#36 and rax_24#25, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_d0#2 (type: long aliased: False), rax_13#23 (type: long aliased: False), rax_21#14 (type: long aliased: False), var_d0#0 (type: long aliased: False), var_d0#6 (type: long aliased: False)} have out degree zero, namely rax_13#23 and rax_21#14, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_30#2 (type: long aliased: False), var_30#6 (type: long aliased: False), rax_6#29 (type: long aliased: False), var_30#0 (type: long aliased: False), rax_16#19 (type: long aliased: False)} have out degree zero, namely rax_6#29 and rax_16#19, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_14#24 (type: long * aliased: False), var_60#0 (type: long * aliased: False), rax_20#12 (type: long * aliased: False), var_60#2 (type: long * aliased: False), var_60#6 (type: long * aliased: False)} have out degree zero, namely rax_14#24 and rax_20#12, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_460#1 (type: void * aliased: False), var_460#4 (type: void * aliased: False), var_460#2 (type: void * aliased: False), var_460#5 (type: void * aliased: False), var_460#0 (type: void * aliased: False)} have out degree zero, namely var_460#1 and var_460#4, i.e., these set of vertices is not an identity group
# 1: networkx.exception.NetworkXError: The node case 0x7: is not in the digraph.
# 1: ValueError: At least two variables in the identity group {0 type: unsigned long, r12#1 (type: unsigned long aliased: False), var_60#6 (type: unsigned long aliased: False), var_60#0 (type: unsigned long aliased: False), var_60#4 (type: unsigned long aliased: False)} have out degree zero, namely 0x0 and r12#1, i.e., these set of vertices is not an identity group
# 1: networkx.exception.NetworkXError: The node case 0x9: is not in the digraph.
# 1: ValueError: At least two variables in the identity group {var_50#8 (type: unsigned long aliased: False), var_50#0 (type: unsigned long aliased: False), var_50#1 (type: unsigned long aliased: False), var_50#7 (type: unsigned long aliased: False), var_50#9 (type: unsigned long aliased: False), var_50#2 (type: unsigned long aliased: False)} have out degree zero, namely var_50#1 and var_50#7, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_30#2 (type: long aliased: False), var_30#6 (type: long aliased: False), var_30#0 (type: long aliased: False), rax_16#10 (type: long aliased: False), rax_24#28 (type: long aliased: False)} have out degree zero, namely rax_16#10 and rax_24#28, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {var_90#2 (type: long * aliased: False), var_90#4 (type: long * aliased: False), var_90#6 (type: long * aliased: False), rdi_1#3 (type: long * aliased: False), var_90#7 (type: long * aliased: False), var_90#0 (type: long * aliased: False)} have out degree zero, namely var_90#6 and rdi_1#3, i.e., these set of vertices is not an identity group
# 1: KeyError: 40
# 1: AssertionError: TrueNode must be a branch of if (!x3)
# 1: ValueError: At least two variables in the identity group {r9_11#8 (type: char * aliased: False), var_70#0 (type: char * aliased: False), rcx_13#12 (type: char * aliased: False), var_70#4 (type: char * aliased: False), var_70#3 (type: char * aliased: False), var_70#6 (type: char * aliased: False), var_40_1#3 (type: char * aliased: False)} have out degree zero, namely r9_11#8 and rcx_13#12, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {r8#20 (type: unsigned long aliased: False), r8#16 (type: unsigned long aliased: False), r8#13 (type: unsigned long aliased: False), r8#6 (type: unsigned long aliased: False), r8#17 (type: unsigned long aliased: False)} have out degree zero, namely r8#6 and r8#17, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {arg3#2 (type: long aliased: False), var_40#0 (type: long aliased: False), var_40#2 (type: long aliased: False), arg3#0 (type: long aliased: False), rax_7#9 (type: long aliased: False)} have out degree zero, namely arg3#0 and rax_7#9, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_28#44 (type: long aliased: False), var_a70#0 (type: long aliased: False), rax_20#25 (type: long aliased: False), var_a70#6 (type: long aliased: False), var_a70#10 (type: long aliased: False), rax_35#12 (type: long aliased: False), var_a70#2 (type: long aliased: False)} have out degree zero, namely rax_28#44 and rax_20#25, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_24#16 (type: long aliased: False), var_30#2 (type: long aliased: False), rax_4#29 (type: long aliased: False), rax_14#5 (type: long aliased: False), var_30#6 (type: long aliased: False), var_30#10 (type: long aliased: False), var_30#0 (type: long aliased: False)} have out degree zero, namely rax_24#16 and rax_4#29, i.e., these set of vertices is not an identity group
# 1: ValueError: At least two variables in the identity group {rax_13#4 (type: long aliased: False), var_30#2 (type: long aliased: False), rax_3#16 (type: long aliased: False), var_30#6 (type: long aliased: False), var_30#0 (type: long aliased: False)} have out degree zero, namely rax_13#4 and rax_3#16, i.e., these set of vertices is not an identity group
# 1: AttributeError: 'NoneType' object has no attribute 'get_string_after_name'
# 1: ValueError: At least two variables in the identity group {r8#13 (type: unsigned long aliased: False), r8#16 (type: unsigned long aliased: False), r8#6 (type: unsigned long aliased: False), r8#17 (type: unsigned long aliased: False), r8#20 (type: unsigned long aliased: False)} have out degree zero, namely r8#6 and r8#17, i.e., these set of vertices is not an identity group
# 1: KeyError: TransitionBlock(-0x1, AST=var_0 = arg2)
# 1: networkx.exception.NetworkXError: The node case 0xa: is not in the digraph.
# 1: ValueError: At least two variables in the identity group {var_50#6 (type: long * aliased: False), var_50#0 (type: long * aliased: False), rax_28#15 (type: long * aliased: False), rax_13#3 (type: long * aliased: False), var_50#2 (type: long * aliased: False)} have out degree zero, namely rax_28#15 and rax_13#3, i.e., these set of vertices is not an identity group
# 1: KeyError: 14813
# 1: networkx.exception.NetworkXError: The node case 0x11: is not in the digraph.

# %% [markdown]
# ## Tracebacks

# %%
print("Unique tracebacks:", len(failed_runs.dewolf_traceback.unique()))
# Out:
# Unique tracebacks: 35

# %%
for index, value in failed_runs.dewolf_traceback.value_counts().items():
    print(f"{value}:", "\n".join(index.strip().split("\n")[-2:]))
# Out:
# 224742:   File "/opt/dewolf/decompiler/frontend/binaryninja/tagging.py", line 30, in run
#     raise RuntimeError(e)
# 4727:   File "/opt/dewolf/decompiler/structures/graphs/rootedgraph.py", line 87, in remove_node
#     assert node is not self.root, "Can not remove the root node!"
# 668:   File "/opt/dewolf/decompiler/structures/interferencegraph.py", line 62, in contract_independent_set
#     raise ValueError(f"The given set of variables is not an independent set. At least two variables interfere!")
# 610:   File "/opt/dewolf/decompiler/pipeline/preprocessing/remove_stack_canary.py", line 73, in _patch_branch_condition
#     raise RuntimeError("did not expect to reach canary check this way")
# 339:   File "/opt/binaryninja/python/binaryninja/binaryview.py", line 8463, in _value_helper
#     raise ValueError("Couldn't find target for type")
# 265:   File "/opt/binaryninja/python/binaryninja/binaryview.py", line 8463, in _value_helper
#     raise ValueError("Couldn't find target for type")
# 37:   File "/opt/dewolf/decompiler/pipeline/dataflowanalysis/identity_elimination.py", line 225, in find_replacement_variable_of_group
#     raise ValueError(message)
# 25:   File "/opt/dewolf/decompiler/pipeline/controlflowanalysis/variable_name_generation.py", line 133, in _hungarian_prefix
#     prefix = self.type_prefix[type(var_type)][var_type.size]
# 18:   File "/opt/dewolf/decompiler/frontend/binaryninja/handlers/calls.py", line 77, in _lift_call_parameter_names
#     clean_type_string_of_parameters = instruction.dest.expr_type.get_string_after_name().strip("()")
# 14:   File "/opt/dewolf/decompiler/pipeline/preprocessing/switch_variable_detection.py", line 117, in find_switch_expression
#     raise ValueError("No switch variable candidate found.")
# 13:   File "/opt/dewolf/decompiler/pipeline/controlflowanalysis/variable_name_generation.py", line 133, in _hungarian_prefix
#     prefix = self.type_prefix[type(var_type)][var_type.size]
# 7:   File "/opt/dewolf/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py", line 929, in predecessors
#     raise NetworkXError(f"The node {n} is not in the digraph.") from err
# 5:   File "/opt/binaryninja/python/binaryninja/mediumlevelil.py", line 3081, in arch
#     return self._arch
# 4:   File "/opt/dewolf/.venv/lib/python3.10/site-packages/z3/z3.py", line 2976, in _to_int_str
#     return str(int(val))
# 3:   File "/opt/dewolf/decompiler/structures/ast/ast_nodes.py", line 284, in sort_children
#     raise ValueError(f"The children of {self} can not be sorted due to circular reachability")
# 3:   File "/opt/dewolf/decompiler/pipeline/preprocessing/compiler_idiom_handling.py", line 92, in _get_replacement_instruction
#     return Assignment(instructions[last_index].destination, BinaryOperation(operation_type, [var, const]))
# 2:   File "/opt/dewolf/decompiler/pipeline/controlflowanalysis/readability_based_refinement.py", line 451, in _get_variable_from_assignment
#     raise ValueError("Did not expect a Constant/Unknown/Operation with more then 1 operand as a ForLoop declaration")
# 2:   File "/opt/dewolf/decompiler/frontend/binaryninja/parser.py", line 50, in _add_basic_block_edges
#     lookup_table[edge.target.source_block.start],
# 2:   File "/opt/dewolf/decompiler/structures/ast/ast_nodes.py", line 274, in children
#     if set(self._sorted_children) != set(children):
# 2:   File "/opt/dewolf/.venv/lib/python3.10/site-packages/z3/z3.py", line 2976, in _to_int_str
#     return str(int(val))
# 2:   File "/opt/dewolf/.venv/lib/python3.10/site-packages/z3/z3.py", line 2976, in _to_int_str
#     return str(int(val))
# 2:   File "/opt/dewolf/decompiler/pipeline/dataflowanalysis/array_access_detection.py", line 295, in _size_in_bytes
#     raise RuntimeError(f"Unexpected size {size}")
# 2:   File "/opt/dewolf/.venv/lib/python3.10/site-packages/networkx/classes/coreviews.py", line 81, in __getitem__
#     return AtlasView(self._atlas[name])
# 2:   File "/opt/dewolf/decompiler/structures/pseudo/typing.py", line 155, in __str__
#     return self.SIZE_TYPES[self.size]
# 1:   File "/opt/dewolf/decompiler/structures/ast/ast_nodes.py", line 284, in sort_children
#     raise ValueError(f"The children of {self} can not be sorted due to circular reachability")
# 1:   File "/opt/dewolf/decompiler/frontend/binaryninja/handlers/calls.py", line 77, in _lift_call_parameter_names
#     clean_type_string_of_parameters = instruction.dest.expr_type.get_string_after_name().strip("()")
# 1:   File "/opt/dewolf/decompiler/structures/pseudo/typing.py", line 155, in __str__
#     return self.SIZE_TYPES[self.size]
# 1:   File "/opt/dewolf/decompiler/structures/ast/syntaxforest.py", line 246, in extract_switch_from_condition_sequence
#     assert seq_node_branch.parent in condition_node.children, f"{seq_node_branch} must be a branch of {condition_node}"
# 1:   File "/opt/dewolf/decompiler/structures/pseudo/typing.py", line 155, in __str__
#     return self.SIZE_TYPES[self.size]
# 1:   File "/opt/dewolf/decompiler/structures/ast/ast_nodes.py", line 274, in children
#     if set(self._sorted_children) != set(children):
# 1:   File "/opt/dewolf/decompiler/structures/ast/syntaxgraph.py", line 75, in parent
#     assert node in self, f"Node {node} is not in the AST."
# 1:   File "/usr/lib/python3.10/ctypes/__init__.py", line 510, in cast
#     return _cast(obj, obj, typ)
# 1:   File "/usr/lib/python3.10/ctypes/__init__.py", line 510, in cast
#     return _cast(obj, obj, typ)
# 1:   File "/opt/dewolf/.venv/lib/python3.10/site-packages/networkx/classes/digraph.py", line 929, in predecessors
#     raise NetworkXError(f"The node {n} is not in the digraph.") from err
# 1:   File "/opt/dewolf/decompiler/structures/graphs/basicblock.py", line 155, in remove_instruction
#     self._instructions.remove(instruction)

# %% [markdown]
# ## Find 5 smallest cases per unique exception

# %%
failed_runs.sort_values("function_size").drop_duplicates("dewolf_exception")


filtered_df = failed_runs.groupby("dewolf_exception").apply(lambda x: x.nsmallest(10, "function_basic_block_count"))
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
#          id         function_name  function_basic_block_count  function_size
# 0         8      __stack_chk_fail                           1             10  \
# 1        79      __stack_chk_fail                           1             10
# 2       234      __stack_chk_fail                           1             10
# 3       328      __stack_chk_fail                           1             10
# 4       417      __stack_chk_fail                           1             10
# ..      ...                   ...                         ...            ...
# 275  252511  ftdi_usb_open_string                          39            728
# 276   47095              sub_3da0                          42            840
# 277   54497              sub_6160                          38           1016
# 278  191785              sub_43b0                          18            376
# 279  566556              sub_3a90                          20            374
#
#     function_arch function_platform
# 0          x86_64      linux-x86_64  \
# 1          x86_64      linux-x86_64
# 2          x86_64      linux-x86_64
# 3          x86_64      linux-x86_64
# 4          x86_64      linux-x86_64
# ..            ...               ...
# 275        x86_64      linux-x86_64
# 276        x86_64      linux-x86_64
# 277        x86_64      linux-x86_64
# 278        x86_64      linux-x86_64
# 279        x86_64      linux-x86_64
#
#                                            sample_hash
# 0    7690a63b03116527b8f3aa95625d36c44250bcbc3eb1d2...  \
# 1    00d64368416328f6891235d725e605021d26eedbbf4f18...
# 2    48ae6c2ee4c1fe9a072fe376bc66824eda5be072524793...
# 3    a46a30a17a093415db567c15b497d48ed9a4e56c41885f...
# 4    6cbd692bcbc3d8d4b7092bc1bd7d14a13df4f29e18402f...
# ..                                                 ...
# 275  121dfa46b9da0745086ac13444228802b83756741d3682...
# 276  2cc4148bcdd7907a4aa9c8fa9a1b653cb6fe0c987f40fb...
# 277  96c1ecedc2e8ec7671b005b5c64e345604b1d39363383b...
# 278  6207f05f2949ce3b51fce179729988b704de606045664b...
# 279  bc9c76c43330197b262edb75b7e5545789b9d352bdcd56...
#
#                                            sample_name
# 0    7690a63b03116527b8f3aa95625d36c44250bcbc3eb1d2...  \
# 1    00d64368416328f6891235d725e605021d26eedbbf4f18...
# 2    48ae6c2ee4c1fe9a072fe376bc66824eda5be072524793...
# 3    a46a30a17a093415db567c15b497d48ed9a4e56c41885f...
# 4    6cbd692bcbc3d8d4b7092bc1bd7d14a13df4f29e18402f...
# ..                                                 ...
# 275  121dfa46b9da0745086ac13444228802b83756741d3682...
# 276  2cc4148bcdd7907a4aa9c8fa9a1b653cb6fe0c987f40fb...
# 277  96c1ecedc2e8ec7671b005b5c64e345604b1d39363383b...
# 278  6207f05f2949ce3b51fce179729988b704de606045664b...
# 279  bc9c76c43330197b262edb75b7e5545789b9d352bdcd56...
#
#                                         dewolf_options
# 0    {\n    "expression-propagation.maximum_instruc...  \
# 1    {\n    "expression-propagation.maximum_instruc...
# 2    {\n    "expression-propagation.maximum_instruc...
# 3    {\n    "expression-propagation.maximum_instruc...
# 4    {\n    "expression-propagation.maximum_instruc...
# ..                                                 ...
# 275  {\n    "expression-propagation.maximum_instruc...
# 276  {\n    "expression-propagation.maximum_instruc...
# 277  {\n    "expression-propagation.maximum_instruc...
# 278  {\n    "expression-propagation.maximum_instruc...
# 279  {\n    "expression-propagation.maximum_instruc...
#
#                         dewolf_current_commit binaryninja_version
# 0    b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469  \
# 1    b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 2    b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 3    b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 4    b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# ..                                        ...                 ...
# 275  b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 276  b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 277  b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 278  b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
# 279  b978d098f2a829650fb82e984bc7fd611c3190ea            3.1.3469
#
#                                       dewolf_exception
# 0      AssertionError: Can not remove the root node!\n  \
# 1      AssertionError: Can not remove the root node!\n
# 2      AssertionError: Can not remove the root node!\n
# 3      AssertionError: Can not remove the root node!\n
# 4      AssertionError: Can not remove the root node!\n
# ..                                                 ...
# 275  networkx.exception.NetworkXError: The node cas...
# 276  networkx.exception.NetworkXError: The node cas...
# 277  networkx.exception.NetworkXError: The node cas...
# 278  networkx.exception.NetworkXError: The node cas...
# 279  networkx.exception.NetworkXError: The node cas...
#
#                                       dewolf_traceback
# 0      File "/opt/dewolf/decompiler/util/bugfinder/...  \
# 1      File "/opt/dewolf/decompiler/util/bugfinder/...
# 2      File "/opt/dewolf/decompiler/util/bugfinder/...
# 3      File "/opt/dewolf/decompiler/util/bugfinder/...
# 4      File "/opt/dewolf/decompiler/util/bugfinder/...
# ..                                                 ...
# 275    File "/opt/dewolf/decompiler/util/bugfinder/...
# 276    File "/opt/dewolf/decompiler/util/bugfinder/...
# 277    File "/opt/dewolf/decompiler/util/bugfinder/...
# 278    File "/opt/dewolf/decompiler/util/bugfinder/...
# 279    File "/opt/dewolf/decompiler/util/bugfinder/...
#
#      dewolf_decompilation_time dewolf_undecorated_code  is_successful
# 0                          NaN                    None              0
# 1                          NaN                    None              0
# 2                          NaN                    None              0
# 3                          NaN                    None              0
# 4                          NaN                    None              0
# ..                         ...                     ...            ...
# 275                        NaN                    None              0
# 276                        NaN                    None              0
# 277                        NaN                    None              0
# 278                        NaN                    None              0
# 279                        NaN                    None              0
#
# [280 rows x 16 columns]

# %%
import pandas as pd
import sqlite3

database_path = 'filtered.db'

with sqlite3.connect(database_path) as conn:
    # TODO: write to table 'commit'
    filtered_df.to_sql('dewolf', conn, index=False, if_exists='replace')
